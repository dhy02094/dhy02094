# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 특성값을 이용한 비선형 분류모델
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# # 다중 분류 모델
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# (원핫인코딩을 했기 때문에 자동으로 0 부분은 지워진다.)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# (matmul이 아니므로 그냥 대응되는 위치에 곱)
# ![image-9.png](attachment:image-9.png)
# (,1)이 아니라 (,0)을 하면 열끼리 더해서 값이 틀려진다.
# ![image-10.png](attachment:image-10.png)
# ### 결과
# ![image-11.png](attachment:image-11.png)

# %% [markdown]
# # 실습

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from ch09 import *
plt.rcParams['figure.figsize'] = (10,10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/f4/fb3b_sqx3rvc3gfr73v6ck_00000gn/T/ipykernel_15522/2761521403.py in <module>
#       2 import matplotlib.pyplot as plt
#       3 import tensorflow as tf
# ----> 4 from ch09 import *
#       5 plt.rcParams['figure.figsize'] = (10,10)
#
# ModuleNotFoundError: No module named 'ch09'
