# %% [markdown]
# # CNN 피쳐맵 중간 과정 보기

# %%
# package and module
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input

# %%
from numpy import expand_dims
from matplotlib import pyplot

# %%
# 레이어 설정
layers = [2,5,9,13,17]
# 출력값 
outputs = [model.layers[i].output for i in layers]
# 모델 재설정
model = Model(inputs=model.inputs, outputs=outputs)

# feature map 시각화 함수
def fmap_visualize(image):
    img = expand_dims(image, axis=0) # expand dimension
    img = preprocess_input(img) # RGB -> BGR and 0 centered
    
    feature_maps = model.predict(img)
    
    square = 8
    for fmap in feature_maps:
        ix=1
        plt.figure(figsize=(10,10))
        for _ in range(square):
            for _ in range(square):
                ax = pyplot.subplot(square,square,ix)
                ax.set_xticks([])
                ax.set_yticks([])
                pyplot.imshow(fmap[0,:,:,ix-1])
                ix += 1
        pyplot.show()

# %%
# 이미지 하나로 각 conv layer feature map 살펴보기
fmap_visualize(train_array[0])

# %% [markdown]
# ![image.png](attachment:image.png)
