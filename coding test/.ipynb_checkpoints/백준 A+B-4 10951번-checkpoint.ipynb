# %% [markdown]
# ![image.png](attachment:image.png)

# %%
while 1: 
    try:
        a,b = map(int, input().split())
        print(a+b)
    except:
        break
# Out:
# 1 1
# 2
# 2 3
# 5
# 3 4
# 7
# 9 8
# 17
# 5 2
# 7
# s
