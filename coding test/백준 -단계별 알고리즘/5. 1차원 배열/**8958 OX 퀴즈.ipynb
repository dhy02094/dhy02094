# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1 입출력
n = int(input())
for i in range(n):
    case = input()
    score = 0
    sum_score = 0
    for j in case:
        if j == 'O':
            score += 1
        else :
            score = 0
        sum_score +=score
    print(sum_score)
# Out:
# 5
# OOXXOXXOOO
# 10
# OOXXOOXXOO
# 9
# OXOXOXOXOXOX
# 6
# OOOOOOOOOOO
# 66
# OOOOXOOOOXOOOOX
# 30
