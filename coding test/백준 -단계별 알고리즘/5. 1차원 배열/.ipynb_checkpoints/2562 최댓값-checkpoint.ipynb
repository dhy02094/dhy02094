# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = []
for i in range(9):
    num.append(int(input()))

print(max(num))
print(num.index(max(num))+1)
# Out:
# 3
# 29
# 38
# 12
# 57
# 74
# 40
# 85
# 61
# 85
# 8
