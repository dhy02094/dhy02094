# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = []
for i in range(3):
    data.append(int(input()))

prod = data[0] * data[1] * data[2]
str_prod = list(str(prod))

for i in range(10):
    print(str_prod.count(str(i)))
# Out:
# 150
# 266
# 427
# 3
# 1
# 0
# 2
# 0
# 0
# 0
# 2
# 0
# 0
