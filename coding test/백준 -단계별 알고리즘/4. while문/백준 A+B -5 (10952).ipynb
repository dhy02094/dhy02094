# %% [markdown]
# ![image.png](attachment:image.png)

# %%
while 1:
    a, b = map(int, input().split())
    if a==0 and b==0:
        break
    else :
        print(a+b)
# Out:
# 1 1
# 2
# 2 3
# 5
# 3 4
# 7
# 9 8
# 17
# 5 2
# 7
# 0 0
