# %%
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
# %matplotlib notebook
import numpy as np
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()

ax = fig.add_subplot(111, projection="3d")


ax.scatter(0,0,420, c="yellow", marker="*")

k=400
Z = [i for i in range(k)]
X = [math.cos(i/5)*(k-i) for i in range(k)]
Y = [math.sin(i/5)*(k-i) for i in range(k)]
ax.scatter(X,Y,Z, c="green", marker="^")
k=400
step = 6
Z = [i for i in range(1,k,step)]
X = [math.cos(i/5+2)*(k-i+10) for i in range(1,k,step)]
Y = [math.sin(i/5+2)*(k-i+10) for i in range(1,k,step)]
ax.scatter(X,Y,Z, c="red", marker="o")

k= 100
Z = [-i*1.3+50 for i in range(k)]
X = [math.cos(i)*k for i in range(k)]
Y = [math.sin(i)*k for i in range(k)]
ax.scatter(X,Y,Z, c="chocolate", marker="^")


x = [np.random.randint(600) for _ in range(100) ]
y = [np.random.randint(600) for _ in range(100) ]
z = [np.random.randint(400) for _ in range(100) ]
ax.scatter(x,y,z, marker='o', s=15, c='grey')



plt.xlim(-700,700)
plt.ylim(-700,700)

ax.set_title("Aivler Merry Christmas !")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
# %matplotlib notebook
import numpy as np

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection="3d")


ax.scatter(0,0,420, c="yellow", marker="*")

k=400
Z = [i for i in range(k)]
X = [math.cos(i/5)*(k-i) for i in range(k)]
Y = [math.sin(i/5)*(k-i) for i in range(k)]
ax.scatter(X,Y,Z, c="green", marker="^")
k=400
step = 6
Z = [i for i in range(1,k,step)]
X = [math.cos(i/5+2)*(k-i+10) for i in range(1,k,step)]
Y = [math.sin(i/5+2)*(k-i+10) for i in range(1,k,step)]
ax.scatter(X,Y,Z, c="red", marker="o")

k= 100
Z = [-i*1.3+50 for i in range(k)]
X = [math.cos(i)*k for i in range(k)]
Y = [math.sin(i)*k for i in range(k)]
ax.scatter(X,Y,Z, c="chocolate", marker="^")


x = [np.random.randint(600) for _ in range(100) ]
y = [np.random.randint(600) for _ in range(100) ]
z = [np.random.randint(400) for _ in range(100) ]
ax.scatter(x,y,z, marker='o', s=15, c='grey')



plt.xlim(-700,700)
plt.ylim(-700,700)

ax.set_title("Aivler Merry Christmas !")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig = plt.figure(figsize=(8,8))

ax = fig.add_subplot(111, projection="3d")

ax.scatter(0,0,417, c="gold", marker="*")
ax.scatter(0,0,418, c="gold", marker="*")
ax.scatter(0,0,419, c="gold", marker="*")
ax.scatter(0,0,419, c="gold", marker="*")
ax.scatter(0,0,420, c="gold", marker="*")
ax.scatter(0,0,421, c="gold", marker="*")

k=300
Z = [i for i in range(k)]
X = [math.cos(i/5)*(k-i) for i in range(k)]
Y = [math.sin(i/5)*(k-i) for i in range(k)]
ax.scatter(X,Y,Z, c="green", marker="^")
k=300
step = 7
Z = [i for i in range(1,k,step)]
X = [math.cos(i/5+2)*(k-i+10) for i in range(1,k,step)]
Y = [math.sin(i/5+2)*(k-i+10) for i in range(1,k,step)]
ax.scatter(X,Y,Z, c="coral", marker="o")


k= 100
Z = [-i+20 for i in range(k)]
X = [math.cos(i)*k for i in range(k)]
Y = [math.sin(i)*k for i in range(k)]
ax.scatter(X,Y,Z, c="chocolate", marker="^")


x = [np.random.randint(600) for _ in range(100) ]
y = [np.random.randint(600) for _ in range(100) ]
z = [np.random.randint(400) for _ in range(100) ]
ax.scatter(x,y,z, marker='o', s=15, c='snow')



plt.xlim(-700,700)
plt.ylim(-700,700)


ax.set_title("Aivler Merry Christmas !")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig = plt.figure(figsize=(8,8))

ax = fig.add_subplot(111, projection="3d")

ax.scatter(0,0,417, c="gold", marker="*")
ax.scatter(0,0,418, c="gold", marker="*")
ax.scatter(0,0,419, c="gold", marker="*")
ax.scatter(0,0,422, c="gold", marker="*")
ax.scatter(0,0,420, c="gold", marker="*")
ax.scatter(0,0,421, c="gold", marker="*")

k=400
Z = [i for i in range(k)]
X = [math.cos(i/5)*(k-i) for i in range(k)]
Y = [math.sin(i/5)*(k-i) for i in range(k)]
ax.scatter(X,Y,Z, c="darkgreen", marker="^")
k=400
step = 5
Z = [i for i in range(1,k,step)]
X = [math.cos(i/5+2)*(k-i+10) for i in range(1,k,step)]
Y = [math.sin(i/5+2)*(k-i+10) for i in range(1,k,step)]
ax.scatter(X,Y,Z, c="orangered", marker="o")


k= 80
Z = [-i+30 for i in range(k)]
X = [math.cos(i)*k for i in range(k)]
Y = [math.sin(i)*k for i in range(k)]
ax.scatter(X,Y,Z, c="chocolate", marker="^")


x = [np.random.randint(-600,600) for _ in range(100) ]
y = [np.random.randint(-600,600) for _ in range(100) ]
z = [np.random.randint(100,400) for _ in range(100) ]
ax.scatter(x,y,z, marker='o', s=15, c='lightgrey')



plt.xlim(-700,700)
plt.ylim(-700,700)

plt.axis('off')
ax.set_title("Aivler Merry Christmas !", pad=0.001)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
